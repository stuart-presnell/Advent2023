# %%
# https://adventofcode.com/2023/day/21


import sys
print(sys.version)

import numpy

# My utility functions
# My utility functions
from utils import (
show, 
# chunk_splitlines, printT, showM, showD, unzip, parse_nums, rotate90, close_bracket, cmp, qsort, nwise_cycled,
# Best, 
Timer,
)
# TTT = Timer()

################################

def parse_file_a(filename):
  f = open(filename)
  ip_file = f.read().splitlines()
  f.close()
  for r in range(len(ip_file)):
    if 'S' in ip_file[r]:
      col = ip_file[r].index('S')
      start = (r,col)
      break
  return ip_file, start

test_input = parse_file_a("Puzzle21_test.txt")
input      = parse_file_a("Puzzle21_input.txt")

(M, S) = test_input
# (M, S) = input
# show(M)
# print(S)

ht = len(M)
wd = len(M[0])

def free(r,c):
  if (0 <= r < ht) & (0 <= c < wd):
    return (M[r][c] != '#')
  else:
    return False

# Where could we be standing now?
current = {S}

def step(current):
  '''Return all the free spaces that are 1 step away from a current position.'''
  op = set()
  for (r,c) in current:
    ngb = [(r-1,c), (r+1,c), (r,c-1), (r,c+1)]
    for pos in ngb:
      if free(*pos):
        op.add(pos)
  return op

def n_steps(current, n):
  for _ in range(n):
    current = step(current)
  return current

print(len(n_steps(current, 64))) # 3532

################################
# Part (a)
################################

# def main_a(ip_file):
#   pass

# print(main_a(test_input))  # 
# print(main_a(input))       # 

# TTT.timecheck("Part (a)")  #

################################
# Part (b)
################################

STEPS_TO_TAKE = 26501365

# def main_b(ip_file):
#   pass

# print(main_b(test_input))  # 
# print(main_b(input))       # 

# TTT.timecheck("Part (b)")  #

################################
# Out:
# 3.11.4 (main, Jun 20 2023, 16:51:49) [Clang 14.0.0 (clang-1400.0.29.202)]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/stuartpresnell/Dropbox/Advent_of_Code_2023/Advent2023/Puzzle21/Puzzle_21.py in line 7
#       <a href='file:///Users/stuartpresnell/Dropbox/Advent_of_Code_2023/Advent2023/Puzzle21/Puzzle_21.py?line=3'>4</a> import sys
#       <a href='file:///Users/stuartpresnell/Dropbox/Advent_of_Code_2023/Advent2023/Puzzle21/Puzzle_21.py?line=4'>5</a> print(sys.version)
# ----> <a href='file:///Users/stuartpresnell/Dropbox/Advent_of_Code_2023/Advent2023/Puzzle21/Puzzle_21.py?line=6'>7</a> import numpy
#       <a href='file:///Users/stuartpresnell/Dropbox/Advent_of_Code_2023/Advent2023/Puzzle21/Puzzle_21.py?line=8'>9</a> # My utility functions
#      <a href='file:///Users/stuartpresnell/Dropbox/Advent_of_Code_2023/Advent2023/Puzzle21/Puzzle_21.py?line=9'>10</a> # My utility functions
#      <a href='file:///Users/stuartpresnell/Dropbox/Advent_of_Code_2023/Advent2023/Puzzle21/Puzzle_21.py?line=10'>11</a> from utils import (
#      <a href='file:///Users/stuartpresnell/Dropbox/Advent_of_Code_2023/Advent2023/Puzzle21/Puzzle_21.py?line=11'>12</a> show,
#      <a href='file:///Users/stuartpresnell/Dropbox/Advent_of_Code_2023/Advent2023/Puzzle21/Puzzle_21.py?line=12'>13</a> # chunk_splitlines, printT, showM, showD, unzip, parse_nums, rotate90, close_bracket, cmp, qsort, nwise_cycled,
#      <a href='file:///Users/stuartpresnell/Dropbox/Advent_of_Code_2023/Advent2023/Puzzle21/Puzzle_21.py?line=13'>14</a> # Best,
#      <a href='file:///Users/stuartpresnell/Dropbox/Advent_of_Code_2023/Advent2023/Puzzle21/Puzzle_21.py?line=14'>15</a> Timer,
#      <a href='file:///Users/stuartpresnell/Dropbox/Advent_of_Code_2023/Advent2023/Puzzle21/Puzzle_21.py?line=15'>16</a> )
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# https://adventofcode.com/2023/day/21


import sys
print(sys.version)
print("version: ", sys.executable)


# import numpy

# My utility functions
# My utility functions
from utils import (
show, 
# chunk_splitlines, printT, showM, showD, unzip, parse_nums, rotate90, close_bracket, cmp, qsort, nwise_cycled,
# Best, 
Timer,
)
# TTT = Timer()

################################

def parse_file_a(filename):
  f = open(filename)
  ip_file = f.read().splitlines()
  f.close()
  for r in range(len(ip_file)):
    if 'S' in ip_file[r]:
      col = ip_file[r].index('S')
      start = (r,col)
      break
  return ip_file, start

test_input = parse_file_a("Puzzle21_test.txt")
input      = parse_file_a("Puzzle21_input.txt")

(M, S) = test_input
# (M, S) = input
# show(M)
# print(S)

ht = len(M)
wd = len(M[0])

def free(r,c):
  if (0 <= r < ht) & (0 <= c < wd):
    return (M[r][c] != '#')
  else:
    return False

# Where could we be standing now?
current = {S}

def step(current):
  '''Return all the free spaces that are 1 step away from a current position.'''
  op = set()
  for (r,c) in current:
    ngb = [(r-1,c), (r+1,c), (r,c-1), (r,c+1)]
    for pos in ngb:
      if free(*pos):
        op.add(pos)
  return op

def n_steps(current, n):
  for _ in range(n):
    current = step(current)
  return current

print(len(n_steps(current, 64))) # 3532

################################
# Part (a)
################################

# def main_a(ip_file):
#   pass

# print(main_a(test_input))  # 
# print(main_a(input))       # 

# TTT.timecheck("Part (a)")  #

################################
# Part (b)
################################

STEPS_TO_TAKE = 26501365

# def main_b(ip_file):
#   pass

# print(main_b(test_input))  # 
# print(main_b(input))       # 

# TTT.timecheck("Part (b)")  #

################################
# Out:
# 3.11.4 (main, Jun 20 2023, 16:51:49) [Clang 14.0.0 (clang-1400.0.29.202)]
# version:  /usr/local/opt/python@3.11/bin/python3.11
# 42
